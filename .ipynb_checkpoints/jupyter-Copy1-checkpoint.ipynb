# %%
using Plots
using Optim
using LinearAlgebra
include("markovvec.jl")
# Out:
# markov (generic function with 1 method)

# %%
N = 3000
m = 2
T = 400
iter = 10
velocities = 1000
EE, ratio_tentativas,energies,velocidades = markov(N,m,T,velocities,iter)
# Out:
# loop: 1
# tentativas 0
# valor da variação da energia: -208001.1443066597
# loop: 2
# tentativas 3000
# valor da variação da energia: 984018.7743542194
# loop: 3
# tentativas 6000
# valor da variação da energia: -813471.2604832649
# loop: 4
# tentativas 9000
# valor da variação da energia: -179739.98736310005
# loop: 5
# tentativas 12000
# valor da variação da energia: 607374.1016409397
# loop: 6
# tentativas 15000
# valor da variação da energia: -50022.060180425644
# loop: 7
# tentativas 18000
# valor da variação da energia: 125277.5966603756
# loop: 8
# tentativas 21000
# valor da variação da energia: -768379.5216925144
# loop: 9
# tentativas 24000
# valor da variação da energia: 712942.6373605728
# loop: 10
# tentativas 27000
# valor da variação da energia: -717125.1524138451
# A razão entre sucessos e tentativas é: 1.0
# (Any[-208001.1443066597, 984018.7743542194, -813471.2604832649, -179739.98736310005, 607374.1016409397, -50022.060180425644, 125277.5966603756, -768379.5216925144, 712942.6373605728, -717125.1524138451], 1.0, Any[2.0019018253282027e9, 1.9984653711716669e9, 1.9906932243073144e9, 1.997540552258963e9, 1.9860713062082124e9, 1.9936845081918385e9, 2.011348823551263e9, 2.051212673729326e9, 1.9817187897682552e9, 2.0012565619845414e9], [-366.6325904971086 884.0684497358236; -320.37262936037587 -166.11057525672095; … ; -38.35005003097899 -246.67932155387655; 466.7005867835378 253.47924602710668])

# %%
energies
# Out:
# 10-element Vector{Any}:
#  2.0019018253282027e9
#  1.9984653711716669e9
#  1.9906932243073144e9
#  1.997540552258963e9
#  1.9860713062082124e9
#  1.9936845081918385e9
#  2.011348823551263e9
#  2.051212673729326e9
#  1.9817187897682552e9
#  2.0012565619845414e9

# %%
scalar = []
for i in 1:N
    push!(scalar,norm(velocidades[i,:]))
    end
scalar
# Out:
# 3000-element Vector{Any}:
#   957.0770503114799
#   360.8758025351652
#  1096.8787002383635
#  1206.0356523789073
#   637.023613879102
#   747.6064665449602
#   245.88031271543633
#   349.16982283418633
#   242.94657307575253
#   925.8863061029917
#   203.91276564995874
#  1364.6959783114469
#   747.2927521270846
#     ⋮
#  1019.9532719410445
#   899.1433528733259
#   642.5092059557355
#   942.8517793369385
#   867.6201730890012
#  1147.9388808793035
#   633.2493106622316
#  1164.5726219674004
#   753.5004820913622
#   997.7097706151384
#   249.64257253052696
#   531.0943097704671

# %%
Plots.xlabel!("Velocidades escalar")
Plots.histogram(scalar)

# %% [markdown]
# Para plotar a curva, vai exigir com que eu selecione o intervalo de valores e isso eu posso fazer usando a velocidade que dei de entrada

# %%
mean(scalar)
# Out:
# 763.9432408552713

# %%
N/velocities
# Out:
# 3.0

# %%
scalar
# Out:
# 3000-element Vector{Any}:
#   957.0770503114799
#   360.8758025351652
#  1096.8787002383635
#  1206.0356523789073
#   637.023613879102
#   747.6064665449602
#   245.88031271543633
#   349.16982283418633
#   242.94657307575253
#   925.8863061029917
#   203.91276564995874
#  1364.6959783114469
#   747.2927521270846
#     ⋮
#  1019.9532719410445
#   899.1433528733259
#   642.5092059557355
#   942.8517793369385
#   867.6201730890012
#  1147.9388808793035
#   633.2493106622316
#  1164.5726219674004
#   753.5004820913622
#   997.7097706151384
#   249.64257253052696
#   531.0943097704671

# %%
sort(scalar)
# Out:
# 3000-element Vector{Any}:
#    51.069747806753064
#    60.40834350664721
#    66.69961700758518
#    68.63349049950332
#    68.734712664432
#    69.51977354946634
#    71.19240012522813
#    74.18919661946437
#    75.52620883686733
#    76.49992580470716
#    81.49022250153871
#    91.58128902105013
#    91.66725598543297
#     ⋮
#  1356.156811302433
#  1358.630424942383
#  1364.6959783114469
#  1366.8956667575906
#  1367.8328584866401
#  1369.2263686319031
#  1370.4747897767418
#  1381.1523670100007
#  1386.0597215556802
#  1387.6170370935417
#  1387.9858026911359
#  1391.1079694592033

# %%
teto = floor(maximum(scalar)+1)
# Out:
# 1392.0

# %%
classes = 30
# Out:
# 30

# %%
Δv = teto/(teto/N)
# Out:
# 3000.0

# %%
a = [i*Δv for i in 1:classes]
a
# Out:
# 30-element Vector{Float64}:
#   3000.0
#   6000.0
#   9000.0
#  12000.0
#  15000.0
#  18000.0
#  21000.0
#  24000.0
#  27000.0
#  30000.0
#  33000.0
#  36000.0
#  39000.0
#      ⋮
#  57000.0
#  60000.0
#  63000.0
#  66000.0
#  69000.0
#  72000.0
#  75000.0
#  78000.0
#  81000.0
#  84000.0
#  87000.0
#  90000.0

# %%
frequencias = []
k = 1
f = 0
for i in sort(scalar)
    if i > a[k]
        push!(frequencias,f)
        k += 1
        f = 0
    end
    f +=1
end
push!(frequencias,f)

frequencias
# Out:
# 1-element Vector{Any}:
#  3000

# %%
using Plotly

Plotly.plot(a,frequencias./N)
# Out:
# data: [
#   "scatter with fields type, x, and y"
# ]
#
# layout: "layout with fields margin and template"

# %%
Plotly.plot(1:iter,EE)
# Out:
# data: [
#   "scatter with fields type, x, and y"
# ]
#
# layout: "layout with fields margin and template"

# %%
EE
# Out:
# 10-element Vector{Any}:
#  -208001.1443066597
#   984018.7743542194
#  -813471.2604832649
#  -179739.98736310005
#   607374.1016409397
#   -50022.060180425644
#   125277.5966603756
#  -768379.5216925144
#   712942.6373605728
#  -717125.1524138451
