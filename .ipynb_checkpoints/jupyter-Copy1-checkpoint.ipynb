# %%
using Plots
using Optim
using LinearAlgebra
include("markovvec.jl")
# Out:
# markov (generic function with 1 method)

# %%
N = 3000
m = 2
T = 400
iter = 10
velocities = 1000
EE, ratio_tentativas,energies,velocidades = markov(N,m,T,velocities,iter)
# Out:
# loop: 1
# valor da variação da energia: 40867.71334314346
# ----------------------------------------- condição 2
# tentativa 1
# valor da variação da energia: -659929.377954483
# ----------------------------------------- condição 1
# tentativa 2
# valor da variação da energia: -89751.03135466576
# ----------------------------------------- condição 1
# tentativa 3
# valor da variação da energia: 756070.6958172321
# ----------------------------------------- condição 2
# tentativa 4
# valor da variação da energia: -887013.5435214043
# ----------------------------------------- condição 1
# tentativa 5
# valor da variação da energia: -582873.866445303
# ----------------------------------------- condição 1
# tentativa 6
# valor da variação da energia: -423965.7698881626
# ----------------------------------------- condição 1
# tentativa 7
# valor da variação da energia: -433929.1843135357
# ----------------------------------------- condição 1
# tentativa 8
# valor da variação da energia: -59973.56527900696
# ----------------------------------------- condição 1
# tentativa 9
# valor da variação da energia: -571304.8065874577
# ----------------------------------------- condição 1
# tentativa 10
# valor da variação da energia: -249763.6345257759
# ----------------------------------------- condição 1
# tentativa 11
# valor da variação da energia: -388500.32455301285
# ----------------------------------------- condição 1
# tentativa 12
# valor da variação da energia: 1.647271284142971e6
# ----------------------------------------- condição 2
# tentativa 13
# valor da variação da energia: -835014.3917517662
# ----------------------------------------- condição 1
# tentativa 14
# valor da variação da energia: -239126.7192108631
# ----------------------------------------- condição 1
# tentativa 15
# valor da variação da energia: 21230.893156528473
# ----------------------------------------- condição 2
# tentativa 16
# valor da variação da energia: -742730.2721841335
# ----------------------------------------- condição 1
# tentativa 17
# valor da variação da energia: -627559.7016031742
# ----------------------------------------- condição 1
# tentativa 18
# valor da variação da energia: -523313.06010079384
# ----------------------------------------- condição 1
# tentativa 19
# valor da variação da energia: 176921.27107858658
# ----------------------------------------- condição 2
# tentativa 20
# valor da variação da energia: 266084.92877316475
# ----------------------------------------- condição 2
# tentativa 21
# valor da variação da energia: 98567.4095480442
# ----------------------------------------- condição 2
# tentativa 22
# valor da variação da energia: 179128.24931454659
# ----------------------------------------- condição 2
# tentativa 23
# valor da variação da energia: -25211.665605306625
# ----------------------------------------- condição 1
# tentativa 24
# valor da variação da energia: 33758.3013882637
# ----------------------------------------- condição 2
# tentativa 25
# valor da variação da energia: -520732.63323044777
# ----------------------------------------- condição 1
# tentativa 26
# valor da variação da energia: -57699.529307842255
# ----------------------------------------- condição 1
# tentativa 27
# valor da variação da energia: -164466.42032122612
# ----------------------------------------- condição 1
# tentativa 28
# valor da variação da energia: 262312.862634182
# ----------------------------------------- condição 2
# tentativa 29
# valor da variação da energia: 869736.1971487999
# ----------------------------------------- condição 2
# tentativa 30
# valor da variação da energia: 6766.101044178009
# ----------------------------------------- condição 2
# tentativa 31
# valor da variação da energia: 103094.05360651016
# ----------------------------------------- condição 2
# tentativa 32
# valor da variação da energia: 724564.2323708534
# ----------------------------------------- condição 2
# tentativa 33
# valor da variação da energia: 981411.1477355957
# ----------------------------------------- condição 2
# tentativa 34
# valor da variação da energia: 147707.66964578629
# ----------------------------------------- condição 2
# tentativa 35
# valor da variação da energia: 526301.2776794434
# ----------------------------------------- condição 2
# tentativa 36
# valor da variação da energia: 246677.8106789589
# ----------------------------------------- condição 2
# tentativa 37
# valor da variação da energia: -703671.1145889759
# ----------------------------------------- condição 1
# tentativa 38
# valor da variação da energia: 721643.0818300247
# ----------------------------------------- condição 2
# tentativa 39
# valor da variação da energia: 406875.4680635929
# ----------------------------------------- condição 2
# tentativa 40
# valor da variação da energia: 74990.65194272995
# ----------------------------------------- condição 2
# tentativa 41
# valor da variação da energia: 80973.12862682343
# ----------------------------------------- condição 2
# tentativa 42
# valor da variação da energia: -359521.4291934967
# ----------------------------------------- condição 1
# tentativa 43
# valor da variação da energia: 846654.2947444916
# ----------------------------------------- condição 2
# tentativa 44
# valor da variação da energia: 478277.3705165386
# ----------------------------------------- condição 2
# tentativa 45
# valor da variação da energia: -129103.06398582458
# ----------------------------------------- condição 1
# tentativa 46
# valor da variação da energia: 850359.1392085552
# ----------------------------------------- condição 2
# tentativa 47
# valor da variação da energia: 198487.3483850956
# ----------------------------------------- condição 2
# tentativa 48
# valor da variação da energia: -919562.7457191944
# ----------------------------------------- condição 1
# tentativa 49
# valor da variação da energia: 273641.9854450226
# ----------------------------------------- condição 2
# tentativa 50
# valor da variação da energia: -791286.8276336193
# ----------------------------------------- condição 1
# tentativa 51
# valor da variação da energia: 49065.309386491776
# ----------------------------------------- condição 2
# tentativa 52
# valor da variação da energia: 32460.52264738083
# ----------------------------------------- condição 2
# tentativa 53
# valor da variação da energia: 177034.31048965454
# ----------------------------------------- condição 2
# tentativa 54
# valor da variação da energia: 455157.1130514145
# ----------------------------------------- condição 2
# tentativa 55
# valor da variação da energia: -871193.2840025425
# ----------------------------------------- condição 1
# tentativa 56
# valor da variação da energia: -656358.5251891613
# ----------------------------------------- condição 1
# tentativa 57
# valor da variação da energia: 668379.4504320621
# ----------------------------------------- condição 2
# tentativa 58
# valor da variação da energia: -859072.8825058937
# ----------------------------------------- condição 1
# tentativa 59
# valor da variação da energia: 218092.09659075737
# ----------------------------------------- condição 2
# tentativa 60
# valor da variação da energia: 1.108319689849615e6
# ----------------------------------------- condição 2
# tentativa 61
# valor da variação da energia: -453536.4417209625
# ----------------------------------------- condição 1
# tentativa 62
# valor da variação da energia: 405242.2111814022
# ----------------------------------------- condição 2
# tentativa 63
# valor da variação da energia: 389174.7702848911
# ----------------------------------------- condição 2
# tentativa 64
# valor da variação da energia: 63215.6582801342
# ----------------------------------------- condição 2
# tentativa 65
# valor da variação da energia: 406991.7113304138
# ----------------------------------------- condição 2
# tentativa 66
# valor da variação da energia: -588693.9854047298
# ----------------------------------------- condição 1
# tentativa 67
# valor da variação da energia: 51715.14056682587
# ----------------------------------------- condição 2
# tentativa 68
# valor da variação da energia: -92893.177038908
# ----------------------------------------- condição 1
# tentativa 69
# valor da variação da energia: -1.0473641091775894e6
# ----------------------------------------- condição 1
# tentativa 70
# valor da variação da energia: 449833.3154501915
# ----------------------------------------- condição 2
# tentativa 71
# valor da variação da energia: 708617.5492532253
# ----------------------------------------- condição 2
# tentativa 72
# valor da variação da energia: -899481.5071327686
# ----------------------------------------- condição 1
# tentativa 73
# valor da variação da energia: -908797.8556685448
# ----------------------------------------- condição 1
# tentativa 74
# valor da variação da energia: 685192.3025228977
# ----------------------------------------- condição 2
# tentativa 75
# valor da variação da energia: 3283.9050676822662
# ----------------------------------------- condição 2
# tentativa 76
# valor da variação da energia: 1.0739433800923824e6
# ----------------------------------------- condição 2
# tentativa 77
# valor da variação da energia: 782497.9644687176
# ----------------------------------------- condição 2
# tentativa 78
# valor da variação da energia: 684876.1080543995
# ----------------------------------------- condição 2
# tentativa 79
# valor da variação da energia: 364169.0924232006
# ----------------------------------------- condição 2
# tentativa 80
# valor da variação da energia: -48114.16553783417
# ----------------------------------------- condição 1
# tentativa 81
# valor da variação da energia: 739390.9926054478
# ----------------------------------------- condição 2
# tentativa 82
# valor da variação da energia: -28128.77276659012
# ----------------------------------------- condição 1
# tentativa 83
# valor da variação da energia: 530465.7731077671
# ----------------------------------------- condição 2
# tentativa 84
# valor da variação da energia: -661914.0480251312
# ----------------------------------------- condição 1
# tentativa 85
# valor da variação da energia: -692942.3197932243
# ----------------------------------------- condição 1
# tentativa 86
# valor da variação da energia: 601759.5192403793
# ----------------------------------------- condição 2
# tentativa 87
# valor da variação da energia: -624138.9846804142
# ----------------------------------------- condição 1
# tentativa 88
# valor da variação da energia: 730732.3657033443
# ----------------------------------------- condição 2
# tentativa 89
# valor da variação da energia: -633492.0885696411
# ----------------------------------------- condição 1
# tentativa 90
# valor da variação da energia: 394530.257414341
# ----------------------------------------- condição 2
# tentativa 91
# valor da variação da energia: -329535.2780754566
# ----------------------------------------- condição 1
# tentativa 92
# valor da variação da energia: 36597.15944457054
# ----------------------------------------- condição 2
# tentativa 93
# valor da variação da energia: 384243.8856739998
# ----------------------------------------- condição 2
# tentativa 94
# valor da variação da energia: -140269.63997793198
# ----------------------------------------- condição 1
# tentativa 95
# valor da variação da energia: -542049.2735536098
# ----------------------------------------- condição 1
# tentativa 96
# valor da variação da energia: -87445.50917863846
# ----------------------------------------- condição 1
# tentativa 97
# valor da variação da energia: 344562.1664471626
# ----------------------------------------- condição 2
# tentativa 98
# valor da variação da energia: -94270.03558731079
# ----------------------------------------- condição 1
# tentativa 99
# valor da variação da energia: 270475.58537817
# ----------------------------------------- condição 2
# tentativa 100
# valor da variação da energia: -420502.73256993294
# ----------------------------------------- condição 1
# tentativa 101
# valor da variação da energia: -1815.9506769180298
# ----------------------------------------- condição 1
# tentativa 102
# valor da variação da energia: -101363.27289128304
# ----------------------------------------- condição 1
# tentativa 103
# valor da variação da energia: 889084.3624432087
# ----------------------------------------- condição 2
# tentativa 104
# valor da variação da energia: -35902.50416946411
# ----------------------------------------- condição 1
# tentativa 105
# valor da variação da energia: -364792.92814302444
# ----------------------------------------- condição 1
# tentativa 106
# valor da variação da energia: -619240.9300854206
# ----------------------------------------- condição 1
# tentativa 107
# valor da variação da energia: -48464.985498189926
# ----------------------------------------- condição 1
# tentativa 108
# valor da variação da energia: 189333.93813848495
# ----------------------------------------- condição 2
# tentativa 109
# valor da variação da energia: -723751.7815122604
# ----------------------------------------- condição 1
# tentativa 110
# valor da variação da energia: 199785.7381362915
# ----------------------------------------- condição 2
# tentativa 111
# valor da variação da energia: 102752.63919639587
# ----------------------------------------- condição 2
# tentativa 112
# valor da variação da energia: -740876.7875504494
# ----------------------------------------- condição 1
# tentativa 113
# valor da variação da energia: -222524.46544384956
# ----------------------------------------- condição 1
# tentativa 114
# valor da variação da energia: 581903.9497935772
# ----------------------------------------- condição 2
# tentativa 115
# valor da variação da energia: -279846.816601038
# ----------------------------------------- condição 1
# tentativa 116
# valor da variação da energia: -675867.4774544239
# ----------------------------------------- condição 1
# tentativa 117
# valor da variação da energia: 727163.3388421535
# ----------------------------------------- condição 2
# tentativa 118
# valor da variação da energia: 35174.792318582535
# ----------------------------------------- condição 2
# tentativa 119
# valor da variação da energia: 182458.9032998085
# ----------------------------------------- condição 2
# tentativa 120
# valor da variação da energia: 626804.120300293
# ----------------------------------------- condição 2
# tentativa 121
# valor da variação da energia: 437872.030272007
# ----------------------------------------- condição 2
# tentativa 122
# valor da variação da energia: 347653.98093128204
# ----------------------------------------- condição 2
# tentativa 123
# valor da variação da energia: -641816.4139180183
# ----------------------------------------- condição 1
# tentativa 124
# valor da variação da energia: -45815.51899123192
# ----------------------------------------- condição 1
# tentativa 125
# valor da variação da energia: -187801.72499799728
# ----------------------------------------- condição 1
# tentativa 126
# valor da variação da energia: -557825.9785590172
# ----------------------------------------- condição 1
# tentativa 127
# valor da variação da energia: -75601.3408381939
# ----------------------------------------- condição 1
# tentativa 128
# valor da variação da energia: -1.0688714487817287e6
# ----------------------------------------- condição 1
# tentativa 129
# valor da variação da energia: 602859.2952501774
# ----------------------------------------- condição 2
# tentativa 130
# valor da variação da energia: 868603.5862190723
# ----------------------------------------- condição 2
# tentativa 131
# valor da variação da energia: 186737.15222883224
# ----------------------------------------- condição 2
# tentativa 132
# valor da variação da energia: -219726.53090667725
# ----------------------------------------- condição 1
# tentativa 133
# valor da variação da energia: -126346.51157927513
# ----------------------------------------- condição 1
# tentativa 134
# valor da variação da energia: 292352.3972661495
# ----------------------------------------- condição 2
# tentativa 135
# valor da variação da energia: -107247.0900194645
# ----------------------------------------- condição 1
# tentativa 136
# valor da variação da energia: -1.107158619758606e6
# ----------------------------------------- condição 1
# tentativa 137
# valor da variação da energia: -262054.65584993362
# ----------------------------------------- condição 1
# tentativa 138
# valor da variação da energia: 404525.5399532318
# ----------------------------------------- condição 2
# tentativa 139
# valor da variação da energia: 499373.55739188194
# ----------------------------------------- condição 2
# tentativa 140
# valor da variação da energia: 316006.3632264137
# ----------------------------------------- condição 2
# tentativa 141
# valor da variação da energia: -76476.95688843727
# ----------------------------------------- condição 1
# tentativa 142
# valor da variação da energia: -66007.20175123215
# ----------------------------------------- condição 1
# tentativa 143
# valor da variação da energia: -948738.2833321095
# ----------------------------------------- condição 1
# tentativa 144
# valor da variação da energia: 420427.5751826763
# ----------------------------------------- condição 2
# tentativa 145
# valor da variação da energia: -543660.362184763
# ----------------------------------------- condição 1
# tentativa 146
# valor da variação da energia: 85810.82368040085
# ----------------------------------------- condição 2
# tentativa 147
# valor da variação da energia: 303863.4553141594
# ----------------------------------------- condição 2
# tentativa 148
# valor da variação da energia: -761208.0415112972
# ----------------------------------------- condição 1
# tentativa 149
# valor da variação da energia: 107212.60703730583
# ----------------------------------------- condição 2
# tentativa 150
# valor da variação da energia: -82485.19306373596
# ----------------------------------------- condição 1
# tentativa 151
# valor da variação da energia: 214552.31122374535
# ----------------------------------------- condição 2
# tentativa 152
# valor da variação da energia: 188668.41775274277
# ----------------------------------------- condição 2
# tentativa 153
# valor da variação da energia: 1.1575583532755375e6
# ----------------------------------------- condição 2
# tentativa 154
# valor da variação da energia: -547881.1275720596
# ----------------------------------------- condição 1
# tentativa 155
# valor da variação da energia: 641807.9002649784
# ----------------------------------------- condição 2
# tentativa 156
# valor da variação da energia: 293393.0545692444
# ----------------------------------------- condição 2
# tentativa 157
# valor da variação da energia: -761733.3479523659
# ----------------------------------------- condição 1
# tentativa 158
# valor da variação da energia: -1.1499964913771152e6
# ----------------------------------------- condição 1
# tentativa 159
# valor da variação da energia: -157682.8763179779
# ----------------------------------------- condição 1
# tentativa 160
# valor da variação da energia: -11102.693991661072
# ----------------------------------------- condição 1
# tentativa 161
# valor da variação da energia: -133769.13794064522
# ----------------------------------------- condição 1
# tentativa 162
# valor da variação da energia: 943381.3740491867
# ----------------------------------------- condição 2
# tentativa 163
# valor da variação da energia: -27147.041969060898
# ----------------------------------------- condição 1
# tentativa 164
# valor da variação da energia: 544941.1689083576
# ----------------------------------------- condição 2
# tentativa 165
# valor da variação da energia: 78260.92295312881
# ----------------------------------------- condição 2
# tentativa 166
# valor da variação da energia: 424096.50282502174
# ----------------------------------------- condição 2
# tentativa 167
# valor da variação da energia: 821739.2449138165
# ----------------------------------------- condição 2
# tentativa 168
# valor da variação da energia: 38984.44726419449
# ----------------------------------------- condição 2
# tentativa 169
# valor da variação da energia: -659988.0976202488
# ----------------------------------------- condição 1
# tentativa 170
# valor da variação da energia: -267082.1126382351
# ----------------------------------------- condição 1
# tentativa 171
# valor da variação da energia: 1.1589035155522823e6
# ----------------------------------------- condição 2
# tentativa 172
# valor da variação da energia: -47489.214217185974
# ----------------------------------------- condição 1
# tentativa 173
# valor da variação da energia: -1.219066572184801e6
# ----------------------------------------- condição 1
# tentativa 174
# valor da variação da energia: 211365.80778837204
# ----------------------------------------- condição 2
# tentativa 175
# valor da variação da energia: -61611.67943096161
# ----------------------------------------- condição 1
# tentativa 176
# valor da variação da energia: -130493.13206195831
# ----------------------------------------- condição 1
# tentativa 177
# valor da variação da energia: 525791.8933985233
# ----------------------------------------- condição 2
# tentativa 178
# valor da variação da energia: -249689.73210716248
# ----------------------------------------- condição 1
# tentativa 179
# valor da variação da energia: 839067.3608181477
# ----------------------------------------- condição 2
# tentativa 180
# valor da variação da energia: 765036.9870700836
# ----------------------------------------- condição 2
# tentativa 181
# valor da variação da energia: -711444.0693302155
# ----------------------------------------- condição 1
# tentativa 182
# valor da variação da energia: 79393.86146712303
# ----------------------------------------- condição 2
# tentativa 183
# valor da variação da energia: 490051.2505338192
# ----------------------------------------- condição 2
# tentativa 184
# valor da variação da energia: -333137.38598132133
# ----------------------------------------- condição 1
# tentativa 185
# valor da variação da energia: -523454.64317059517
# ----------------------------------------- condição 1
# tentativa 186
# valor da variação da energia: -146316.45210075378
# ----------------------------------------- condição 1
# tentativa 187
# valor da variação da energia: 899686.0321054459
# ----------------------------------------- condição 2
# tentativa 188
# valor da variação da energia: 1.290515541355133e6
# ----------------------------------------- condição 2
# tentativa 189
# valor da variação da energia: 845676.3167333603
# ----------------------------------------- condição 2
# tentativa 190
# valor da variação da energia: -1.1732562874364853e6
# ----------------------------------------- condição 1
# tentativa 191
# valor da variação da energia: -527797.6677331924
# ----------------------------------------- condição 1
# tentativa 192
# valor da variação da energia: -201794.0248169899
# ----------------------------------------- condição 1
# tentativa 193
# valor da variação da energia: 518932.9925069809
# ----------------------------------------- condição 2
# tentativa 194
# valor da variação da energia: 955730.6643633842
# ----------------------------------------- condição 2
# tentativa 195
# valor da variação da energia: -1.1925755668365955e6
# ----------------------------------------- condição 1
# tentativa 196
# valor da variação da energia: -52268.81438732147
# ----------------------------------------- condição 1
# tentativa 197
# valor da variação da energia: -422192.53201937675
# ----------------------------------------- condição 1
# tentativa 198
# valor da variação da energia: -20250.06341791153
# ----------------------------------------- condição 1
# tentativa 199
# valor da variação da energia: 52171.775331020355
# ----------------------------------------- condição 2
# tentativa 200
# valor da variação da energia: -331214.8661894798
# ----------------------------------------- condição 1
# tentativa 201
# valor da variação da energia: 255998.40224456787
# ----------------------------------------- condição 2
# tentativa 202
# valor da variação da energia: 42000.307784318924
# ----------------------------------------- condição 2
# tentativa 203
# valor da variação da energia: -461345.40159988403
# ----------------------------------------- condição 1
# tentativa 204
# valor da variação da energia: 1.4968596657743454e6
# ----------------------------------------- condição 2
# tentativa 205
# valor da variação da energia: 847270.0251579285
# ----------------------------------------- condição 2
# tentativa 206
# valor da variação da energia: 64238.66852402687
# ----------------------------------------- condição 2
# tentativa 207
# valor da variação da energia: -171568.37819814682
# ----------------------------------------- condição 1
# tentativa 208
# valor da variação da energia: 1.2236103554825783e6
# ----------------------------------------- condição 2
# tentativa 209
# valor da variação da energia: 302432.50522971153
# ----------------------------------------- condição 2
# tentativa 210
# valor da variação da energia: -95165.06295371056
# ----------------------------------------- condição 1
# tentativa 211
# valor da variação da energia: 797035.6806557178
# ----------------------------------------- condição 2
# tentativa 212
# valor da variação da energia: 301103.64322400093
# ----------------------------------------- condição 2
# tentativa 213
# valor da variação da energia: -265852.9720683098
# ----------------------------------------- condição 1
# tentativa 214
# valor da variação da energia: 400803.54986810684
# ----------------------------------------- condição 2
# tentativa 215
# valor da variação da energia: 42783.676119327545
# ----------------------------------------- condição 2
# tentativa 216
# valor da variação da energia: -547354.0333383083
# ----------------------------------------- condição 1
# tentativa 217
# valor da variação da energia: 528953.9027173519
# ----------------------------------------- condição 2
# tentativa 218
# valor da variação da energia: -821277.0922338963
# ----------------------------------------- condição 1
# tentativa 219
# valor da variação da energia: 398979.0142569542
# ----------------------------------------- condição 2
# tentativa 220
# valor da variação da energia: 310626.9453957081
# ----------------------------------------- condição 2
# tentativa 221
# valor da variação da energia: -531566.9017267227
# ----------------------------------------- condição 1
# tentativa 222
# valor da variação da energia: 656654.44714427
# ----------------------------------------- condição 2
# tentativa 223
# valor da variação da energia: 173699.5523891449
# ----------------------------------------- condição 2
# tentativa 224
# valor da variação da energia: -112301.81069922447
# ----------------------------------------- condição 1
# tentativa 225
# valor da variação da energia: 278076.4966607094
# ----------------------------------------- condição 2
# tentativa 226
# valor da variação da energia: -460085.91295838356
# ----------------------------------------- condição 1
# tentativa 227
# valor da variação da energia: -213238.2367787361
# ----------------------------------------- condição 1
# tentativa 228
# valor da variação da energia: -863633.3599026203
# ----------------------------------------- condição 1
# tentativa 229
# valor da variação da energia: -874282.7678003311
# ----------------------------------------- condição 1
# tentativa 230
# valor da variação da energia: 993746.1222987175
# ----------------------------------------- condição 2
# tentativa 231
# valor da variação da energia: 704763.7817687988
# ----------------------------------------- condição 2
# tentativa 232
# valor da variação da energia: -555642.0472240448
# ----------------------------------------- condição 1
# tentativa 233
# valor da variação da energia: 1.324505820398569e6
# ----------------------------------------- condição 2
# tentativa 234
# valor da variação da energia: -707246.9759807587
# ----------------------------------------- condição 1
# tentativa 235
# valor da variação da energia: -1.0549978799068928e6
# ----------------------------------------- condição 1
# tentativa 236
# valor da variação da energia: -360364.2263419628
# ----------------------------------------- condição 1
# tentativa 237
# valor da variação da energia: -591320.50689435
# ----------------------------------------- condição 1
# tentativa 238
# valor da variação da energia: 203684.8454232216
# ----------------------------------------- condição 2
# tentativa 239
# valor da variação da energia: 16455.90789413452
# ----------------------------------------- condição 2
# tentativa 240
# valor da variação da energia: 221201.61646795273
# ----------------------------------------- condição 2
# tentativa 241
# valor da variação da energia: -72805.97555494308
# ----------------------------------------- condição 1
# tentativa 242
# valor da variação da energia: -917842.3681776524
# ----------------------------------------- condição 1
# tentativa 243
# valor da variação da energia: -1.0414415904862881e6
# ----------------------------------------- condição 1
# tentativa 244
# valor da variação da energia: 422957.40329527855
# ----------------------------------------- condição 2
# tentativa 245
# valor da variação da energia: 589181.8101656437
# ----------------------------------------- condição 2
# tentativa 246
# valor da variação da energia: -52003.0233566761
# ----------------------------------------- condição 1
# tentativa 247
# valor da variação da energia: -122524.74801874161
# ----------------------------------------- condição 1
# tentativa 248
# valor da variação da energia: -341655.0957968235
# ----------------------------------------- condição 1
# tentativa 249
# valor da variação da energia: 86725.9042108059
# ----------------------------------------- condição 2
# tentativa 250
# valor da variação da energia: -474313.90368795395
# ----------------------------------------- condição 1
# tentativa 251
# valor da variação da energia: -766194.6321673393
# ----------------------------------------- condição 1
# tentativa 252
# valor da variação da energia: 876952.9775776863
# ----------------------------------------- condição 2
# tentativa 253
# valor da variação da energia: 385913.02320837975
# ----------------------------------------- condição 2
# tentativa 254
# valor da variação da energia: 564074.9833579063
# ----------------------------------------- condição 2
# tentativa 255
# valor da variação da energia: -541615.9834914207
# ----------------------------------------- condição 1
# tentativa 256
# valor da variação da energia: -462049.6155471802
# ----------------------------------------- condição 1
# tentativa 257
# valor da variação da energia: 110858.01862597466
# ----------------------------------------- condição 2
# tentativa 258
# valor da variação da energia: 583002.7934215069
# ----------------------------------------- condição 2
# tentativa 259
# valor da variação da energia: -216688.19242858887
# ----------------------------------------- condição 1
# tentativa 260
# valor da variação da energia: -506897.7453567982
# ----------------------------------------- condição 1
# tentativa 261
# valor da variação da energia: -103476.0835571289
# ----------------------------------------- condição 1
# tentativa 262
# valor da variação da energia: -365015.520973444
# ----------------------------------------- condição 1
# tentativa 263
# valor da variação da energia: 202923.80558538437
# ----------------------------------------- condição 2
# tentativa 264
# valor da variação da energia: 752363.5223433971
# ----------------------------------------- condição 2
# tentativa 265
# valor da variação da energia: -929535.9694030285
# ----------------------------------------- condição 1
# tentativa 266
# valor da variação da energia: 109249.51590776443
# ----------------------------------------- condição 2
# tentativa 267
# valor da variação da energia: -1.0457380430400372e6
# ----------------------------------------- condição 1
# tentativa 268
# valor da variação da energia: 1.2816960688796043e6
# ----------------------------------------- condição 2
# tentativa 269
# valor da variação da energia: 20570.65154147148
# ----------------------------------------- condição 2
# tentativa 270
# valor da variação da energia: 94019.2680940628
# ----------------------------------------- condição 2
# tentativa 271
# valor da variação da energia: -346243.6387767792
# ----------------------------------------- condição 1
# tentativa 272
# valor da variação da energia: 533537.930189848
# ----------------------------------------- condição 2
# tentativa 273
# valor da variação da energia: -319894.56887602806
# ----------------------------------------- condição 1
# tentativa 274
# valor da variação da energia: -353050.2908530235
# ----------------------------------------- condição 1
# tentativa 275
# valor da variação da energia: 448141.22059202194
# ----------------------------------------- condição 2
# tentativa 276
# valor da variação da energia: -25770.858082532883
# ----------------------------------------- condição 1
# tentativa 277
# valor da variação da energia: -242333.3617026806
# ----------------------------------------- condição 1
# tentativa 278
# valor da variação da energia: 224282.08093333244
# ----------------------------------------- condição 2
# tentativa 279
# valor da variação da energia: -172284.64640069008
# ----------------------------------------- condição 1
# tentativa 280
# valor da variação da energia: 207482.76007413864
# ----------------------------------------- condição 2
# tentativa 281
# valor da variação da energia: 1.4862873991150856e6
# ----------------------------------------- condição 2
# tentativa 282
# valor da variação da energia: 550031.1265025139
# ----------------------------------------- condição 2
# tentativa 283
# valor da variação da energia: -380768.74355888367
# ----------------------------------------- condição 1
# tentativa 284
# valor da variação da energia: -313213.9531314373
# ----------------------------------------- condição 1
# tentativa 285
# valor da variação da energia: -889330.4076814651
# ----------------------------------------- condição 1
# tentativa 286
# valor da variação da energia: -67812.84702301025
# ----------------------------------------- condição 1
# tentativa 287
# valor da variação da energia: 279436.20365071297
# ----------------------------------------- condição 2
# tentativa 288
# valor da variação da energia: -362140.024487257
# ----------------------------------------- condição 1
# tentativa 289
# valor da variação da energia: 107852.6748034954
# ----------------------------------------- condição 2
# tentativa 290
# valor da variação da energia: -613488.75273633
# ----------------------------------------- condição 1
# tentativa 291
# valor da variação da energia: -853566.4918348789
# ----------------------------------------- condição 1
# tentativa 292
# valor da variação da energia: -690911.235158205
# ----------------------------------------- condição 1
# tentativa 293
# valor da variação da energia: -729789.8879978657
# ----------------------------------------- condição 1
# tentativa 294
# valor da variação da energia: 222456.861877203
# ----------------------------------------- condição 2
# tentativa 295
# valor da variação da energia: 769334.8597300053
# ----------------------------------------- condição 2
# tentativa 296
# valor da variação da energia: 216373.982555151
# ----------------------------------------- condição 2
# tentativa 297
# valor da variação da energia: -1.1547291854469776e6
# ----------------------------------------- condição 1
# tentativa 298
# valor da variação da energia: -446800.9162559509
# ----------------------------------------- condição 1
# tentativa 299
# valor da variação da energia: 867318.1819546223
# ----------------------------------------- condição 2
# tentativa 300
# valor da variação da energia: -222198.80446982384
# ----------------------------------------- condição 1
# tentativa 301
# valor da variação da energia: -1.5397234066216946e6
# ----------------------------------------- condição 1
# tentativa 302
# valor da variação da energia: -838564.3351562023
# ----------------------------------------- condição 1
# tentativa 303
# valor da variação da energia: 16055.438463687897
# ----------------------------------------- condição 2
# tentativa 304
# valor da variação da energia: -352041.3495981693
# ----------------------------------------- condição 1
# tentativa 305
# valor da variação da energia: -257745.97119665146
# ----------------------------------------- condição 1
# tentativa 306
# valor da variação da energia: 589856.8350183964
# ----------------------------------------- condição 2
# tentativa 307
# valor da variação da energia: -540976.5887541771
# ----------------------------------------- condição 1
# tentativa 308
# valor da variação da energia: 747892.9906945229
# ----------------------------------------- condição 2
# tentativa 309
# valor da variação da energia: 169046.4111609459
# ----------------------------------------- condição 2
# tentativa 310
# valor da variação da energia: 300777.6629037857
# ----------------------------------------- condição 2
# tentativa 311
# valor da variação da energia: 706823.1931350231
# ----------------------------------------- condição 2
# tentativa 312
# valor da variação da energia: -102452.41958642006
# ----------------------------------------- condição 1
# tentativa 313
# valor da variação da energia: 580600.9571335316
# ----------------------------------------- condição 2
# tentativa 314
# valor da variação da energia: 295304.98290658
# ----------------------------------------- condição 2
# tentativa 315
# valor da variação da energia: -196356.7746257782
# ----------------------------------------- condição 1
# tentativa 316
# valor da variação da energia: 826715.9028193951
# ----------------------------------------- condição 2
# tentativa 317
# valor da variação da energia: 857826.2383785248
# ----------------------------------------- condição 2
# tentativa 318
# valor da variação da energia: 1.1226469700555801e6
# ----------------------------------------- condição 2
# tentativa 319
# valor da variação da energia: 116191.87365365028
# ----------------------------------------- condição 2
# tentativa 320
# valor da variação da energia: -820802.5056586266
# ----------------------------------------- condição 1
# tentativa 321
# valor da variação da energia: 874115.0295646191
# ----------------------------------------- condição 2
# tentativa 322
# valor da variação da energia: 754221.716997385
# ----------------------------------------- condição 2
# tentativa 323
# valor da variação da energia: 753467.3022072315
# ----------------------------------------- condição 2
# tentativa 324
# valor da variação da energia: -289011.86810040474
# ----------------------------------------- condição 1
# tentativa 325
# valor da variação da energia: 416451.6288907528
# ----------------------------------------- condição 2
# tentativa 326
# valor da variação da energia: -682430.1250305176
# ----------------------------------------- condição 1
# tentativa 327
# valor da variação da energia: -46240.54923224449
# ----------------------------------------- condição 1
# tentativa 328
# valor da variação da energia: 48327.42284154892
# ----------------------------------------- condição 2
# tentativa 329
# valor da variação da energia: -627707.165096283
# ----------------------------------------- condição 1
# tentativa 330
# valor da variação da energia: 812789.6927232742
# ----------------------------------------- condição 2
# tentativa 331
# valor da variação da energia: -304431.07463765144
# ----------------------------------------- condição 1
# tentativa 332
# valor da variação da energia: 488273.04062128067
# ----------------------------------------- condição 2
# tentativa 333
# valor da variação da energia: -251033.24842095375
# ----------------------------------------- condição 1
# tentativa 334
# valor da variação da energia: -104174.35875916481
# ----------------------------------------- condição 1
# tentativa 335
# valor da variação da energia: 1.0675155594525337e6
# ----------------------------------------- condição 2
# tentativa 336
# valor da variação da energia: 270680.22996354103
# ----------------------------------------- condição 2
# tentativa 337
# valor da variação da energia: 1.1399062497441769e6
# ----------------------------------------- condição 2
# tentativa 338
# valor da variação da energia: -510284.17038846016
# ----------------------------------------- condição 1
# tentativa 339
# valor da variação da energia: 709778.4853358269
# ----------------------------------------- condição 2
# tentativa 340
# valor da variação da energia: 235934.63768553734
# ----------------------------------------- condição 2
# tentativa 341
# valor da variação da energia: 134582.52606368065
# ----------------------------------------- condição 2
# tentativa 342
# valor da variação da energia: -162597.7005188465
# ----------------------------------------- condição 1
# tentativa 343
# valor da variação da energia: 168002.0386519432
# ----------------------------------------- condição 2
# tentativa 344
# valor da variação da energia: -257309.57348060608
# ----------------------------------------- condição 1
# tentativa 345
# valor da variação da energia: 536546.1202478409
# ----------------------------------------- condição 2
# tentativa 346
# valor da variação da energia: 248411.65841841698
# ----------------------------------------- condição 2
# tentativa 347
# valor da variação da energia: -246763.57103657722
# ----------------------------------------- condição 1
# tentativa 348
# valor da variação da energia: 494645.8992469311
# ----------------------------------------- condição 2
# tentativa 349
# valor da variação da energia: -87514.91004443169
# ----------------------------------------- condição 1
# tentativa 350
# valor da variação da energia: 540912.1966249943
# ----------------------------------------- condição 2
# tentativa 351
# valor da variação da energia: -108967.40471196175
# ----------------------------------------- condição 1
# tentativa 352
# valor da variação da energia: -1.0201605638847351e6
# ----------------------------------------- condição 1
# tentativa 353
# valor da variação da energia: -29495.14808344841
# ----------------------------------------- condição 1
# tentativa 354
# valor da variação da energia: -432968.9296424389
# ----------------------------------------- condição 1
# tentativa 355
# valor da variação da energia: -117923.20607089996
# ----------------------------------------- condição 1
# tentativa 356
# valor da variação da energia: 500516.8343093395
# ----------------------------------------- condição 2
# tentativa 357
# valor da variação da energia: 684814.573987484
# ----------------------------------------- condição 2
# tentativa 358
# valor da variação da energia: -89736.38617563248
# ----------------------------------------- condição 1
# tentativa 359
# valor da variação da energia: -585542.6689920425
# ----------------------------------------- condição 1
# tentativa 360
# valor da variação da energia: -116588.83752202988
# ----------------------------------------- condição 1
# tentativa 361
# valor da variação da energia: -173873.68553471565
# ----------------------------------------- condição 1
# tentativa 362
# valor da variação da energia: 193149.42414784431
# ----------------------------------------- condição 2
# tentativa 363
# valor da variação da energia: 613842.0695643425
# ----------------------------------------- condição 2
# tentativa 364
# valor da variação da energia: -452202.0000474453
# ----------------------------------------- condição 1
# tentativa 365
# valor da variação da energia: -294050.88837599754
# ----------------------------------------- condição 1
# tentativa 366
# valor da variação da energia: -314637.73096370697
# ----------------------------------------- condição 1
# tentativa 367
# valor da variação da energia: -886289.1198310852
# ----------------------------------------- condição 1
# tentativa 368
# valor da variação da energia: -1.3149767477641106e6
# ----------------------------------------- condição 1
# tentativa 369
# valor da variação da energia: 396908.98345565796
# ----------------------------------------- condição 2
# tentativa 370
# valor da variação da energia: 269808.54804229736
# ----------------------------------------- condição 2
# tentativa 371
# valor da variação da energia: -132761.73574090004
# ----------------------------------------- condição 1
# tentativa 372
# valor da variação da energia: -330057.06439208984
# ----------------------------------------- condição 1
# tentativa 373
# valor da variação da energia: 13790.102454900742
# ----------------------------------------- condição 2
# tentativa 374
# valor da variação da energia: 1.5295978301725388e6
# ----------------------------------------- condição 2
# tentativa 375
# valor da variação da energia: 243837.64397239685
# ----------------------------------------- condição 2
# tentativa 376
# valor da variação da energia: 200005.887809515
# ----------------------------------------- condição 2
# tentativa 377
# valor da variação da energia: 905750.5531344414
# ----------------------------------------- condição 2
# tentativa 378
# valor da variação da energia: 773417.4701693058
# ----------------------------------------- condição 2
# tentativa 379
# valor da variação da energia: -10508.996504306793
# ----------------------------------------- condição 1
# tentativa 380
# valor da variação da energia: 881374.1406388283
# ----------------------------------------- condição 2
# tentativa 381
# valor da variação da energia: -47149.33118247986
# ----------------------------------------- condição 1
# tentativa 382
# valor da variação da energia: 833172.7124886513
# ----------------------------------------- condição 2
# tentativa 383
# valor da variação da energia: 572613.0171833038
# ----------------------------------------- condição 2
# tentativa 384
# valor da variação da energia: -147836.54763889313
# ----------------------------------------- condição 1
# tentativa 385
# valor da variação da energia: -575309.5495457649
# ----------------------------------------- condição 1
# tentativa 386
# valor da variação da energia: 403291.4328327179
# ----------------------------------------- condição 2
# tentativa 387
# valor da variação da energia: -1.0798103151111603e6
# ----------------------------------------- condição 1
# tentativa 388
# valor da variação da energia: -1.3358506668965816e6
# ----------------------------------------- condição 1
# tentativa 389
# valor da variação da energia: -40666.55195689201
# ----------------------------------------- condição 1
# tentativa 390
# valor da variação da energia: -307786.56458091736
# ----------------------------------------- condição 1
# tentativa 391
# valor da variação da energia: 610211.079269886
# ----------------------------------------- condição 2
# tentativa 392
# valor da variação da energia: 406134.0321085453
# ----------------------------------------- condição 2
# tentativa 393
# valor da variação da energia: -890192.4109122753
# ----------------------------------------- condição 1
# tentativa 394
# valor da variação da energia: -813630.6908841133
# ----------------------------------------- condição 1
# tentativa 395
# valor da variação da energia: -291997.04216837883
# ----------------------------------------- condição 1
# tentativa 396
# valor da variação da energia: 259435.366219759
# ----------------------------------------- condição 2
# tentativa 397
# valor da variação da energia: -1.0860548102855682e6
# ----------------------------------------- condição 1
# tentativa 398
# valor da variação da energia: -1.0465093880403042e6
# ----------------------------------------- condição 1
# tentativa 399
# valor da variação da energia: 420387.9861562252
# ----------------------------------------- condição 2
# tentativa 400
# valor da variação da energia: -1.0419272576701641e6
# ----------------------------------------- condição 1
# tentativa 401
# valor da variação da energia: 610019.4610686302
# ----------------------------------------- condição 2
# tentativa 402
# valor da variação da energia: 527893.3780064583
# ----------------------------------------- condição 2
# tentativa 403
# valor da variação da energia: 453287.8335182667
# ----------------------------------------- condição 2
# tentativa 404
# valor da variação da energia: -417138.99192738533
# ----------------------------------------- condição 1
# tentativa 405
# valor da variação da energia: 377269.0432460308
# ----------------------------------------- condição 2
# tentativa 406
# valor da variação da energia: -507798.1265473366
# ----------------------------------------- condição 1
# tentativa 407
# valor da variação da energia: -686992.8074450493
# ----------------------------------------- condição 1
# tentativa 408
# valor da variação da energia: 104732.46097946167
# ----------------------------------------- condição 2
# tentativa 409
# valor da variação da energia: 459900.154279232
# ----------------------------------------- condição 2
# tentativa 410
# valor da variação da energia: -737543.4139711857
# ----------------------------------------- condição 1
# tentativa 411
# valor da variação da energia: 385586.16021871567
# ----------------------------------------- condição 2
# tentativa 412
# valor da variação da energia: 190776.56840896606
# ----------------------------------------- condição 2
# tentativa 413
# valor da variação da energia: -16254.490583896637
# ----------------------------------------- condição 1
# tentativa 414
# valor da variação da energia: 789308.2344093323
# ----------------------------------------- condição 2
# ...
# ----------------------------------------- condição 1
# tentativa 4212
# valor da variação da energia: -317200.8797416687
# ----------------------------------------- condição 1
# tentativa 4213
# valor da variação da energia: 143696.55371499062
# ----------------------------------------- condição 2
# tentativa 4214
# valor da variação da energia: 753468.4796087742
# ----------------------------------------- condição 2
# tentativa 4215
# valor da variação da energia: 631692.5760173798
# ----------------------------------------- condição 2
# tentativa 4216
# valor da variação da energia: 173555.75345993042
# ----------------------------------------- condição 2
# tentativa 4217
# valor da variação da energia: -118306.78605341911
# ----------------------------------------- condição 1
# tentativa 4218
# valor da variação da energia: 782789.4764940739
# ----------------------------------------- condição 2
# tentativa 4219
# valor da variação da energia: -877854.2356903553
# ----------------------------------------- condição 1
# tentativa 4220
# valor da variação da energia: -436947.8246805668
# ----------------------------------------- condição 1
# tentativa 4221
# valor da variação da energia: 629966.8327713013
# ----------------------------------------- condição 2
# tentativa 4222
# valor da variação da energia: 754924.9432914257
# ----------------------------------------- condição 2
# tentativa 4223
# valor da variação da energia: 826618.0672869682
# ----------------------------------------- condição 2
# tentativa 4224
# valor da variação da energia: 1.0232327028963566e6
# ----------------------------------------- condição 2
# tentativa 4225
# valor da variação da energia: 234532.18188738823
# ----------------------------------------- condição 2
# tentativa 4226
# valor da variação da energia: 504532.77922797203
# ----------------------------------------- condição 2
# tentativa 4227
# valor da variação da energia: 484050.0818243027
# ----------------------------------------- condição 2
# tentativa 4228
# valor da variação da energia: 328939.0041027069
# ----------------------------------------- condição 2
# tentativa 4229
# valor da variação da energia: 815037.3171849251
# ----------------------------------------- condição 2
# tentativa 4230
# valor da variação da energia: 163456.77186226845
# ----------------------------------------- condição 2
# tentativa 4231
# valor da variação da energia: -387377.7289032936
# ----------------------------------------- condição 1
# tentativa 4232
# valor da variação da energia: -753947.9090981483
# ----------------------------------------- condição 1
# tentativa 4233
# valor da variação da energia: -966693.7909462452
# ----------------------------------------- condição 1
# tentativa 4234
# valor da variação da energia: 391831.81419825554
# ----------------------------------------- condição 2
# tentativa 4235
# valor da variação da energia: 263080.10387921333
# ----------------------------------------- condição 2
# tentativa 4236
# valor da variação da energia: 16955.554597377777
# ----------------------------------------- condição 2
# tentativa 4237
# valor da variação da energia: 765163.3288195133
# ----------------------------------------- condição 2
# tentativa 4238
# valor da variação da energia: 1.1740491987128258e6
# ----------------------------------------- condição 2
# tentativa 4239
# valor da variação da energia: -234783.66280651093
# ----------------------------------------- condição 1
# tentativa 4240
# valor da variação da energia: -30799.589181423187
# ----------------------------------------- condição 1
# tentativa 4241
# valor da variação da energia: 569724.6770069599
# ----------------------------------------- condição 2
# tentativa 4242
# valor da variação da energia: -638915.9666528702
# ----------------------------------------- condição 1
# tentativa 4243
# valor da variação da energia: 634787.7471163273
# ----------------------------------------- condição 2
# tentativa 4244
# valor da variação da energia: 1.215663025767088e6
# ----------------------------------------- condição 2
# tentativa 4245
# valor da variação da energia: 1.0502795859277248e6
# ----------------------------------------- condição 2
# tentativa 4246
# valor da variação da energia: 926355.8160440922
# ----------------------------------------- condição 2
# tentativa 4247
# valor da variação da energia: 304546.5487101078
# ----------------------------------------- condição 2
# tentativa 4248
# valor da variação da energia: -543429.0192029476
# ----------------------------------------- condição 1
# tentativa 4249
# valor da variação da energia: -56084.37260270119
# ----------------------------------------- condição 1
# tentativa 4250
# valor da variação da energia: 333652.20676732063
# ----------------------------------------- condição 2
# tentativa 4251
# valor da variação da energia: 217255.30969548225
# ----------------------------------------- condição 2
# tentativa 4252
# valor da variação da energia: 405945.80364871025
# ----------------------------------------- condição 2
# tentativa 4253
# valor da variação da energia: 796400.5399024487
# ----------------------------------------- condição 2
# tentativa 4254
# valor da variação da energia: 558482.5392622948
# ----------------------------------------- condição 2
# tentativa 4255
# valor da variação da energia: -1.373033689752102e6
# ----------------------------------------- condição 1
# tentativa 4256
# valor da variação da energia: 609139.3716185093
# ----------------------------------------- condição 2
# tentativa 4257
# valor da variação da energia: -96092.29428195953
# ----------------------------------------- condição 1
# tentativa 4258
# valor da variação da energia: 918541.7442970276
# ----------------------------------------- condição 2
# tentativa 4259
# valor da variação da energia: 452109.3318862915
# ----------------------------------------- condição 2
# tentativa 4260
# valor da variação da energia: -1.0454732853078842e6
# ----------------------------------------- condição 1
# tentativa 4261
# valor da variação da energia: 648520.9703946114
# ----------------------------------------- condição 2
# tentativa 4262
# valor da variação da energia: -369928.675167799
# ----------------------------------------- condição 1
# tentativa 4263
# valor da variação da energia: 619216.1663019657
# ----------------------------------------- condição 2
# tentativa 4264
# valor da variação da energia: 178867.1866312027
# ----------------------------------------- condição 2
# tentativa 4265
# valor da variação da energia: -551630.3454971313
# ----------------------------------------- condição 1
# tentativa 4266
# valor da variação da energia: -530196.4442126751
# ----------------------------------------- condição 1
# tentativa 4267
# valor da variação da energia: -606320.142977953
# ----------------------------------------- condição 1
# tentativa 4268
# valor da variação da energia: -128303.73548412323
# ----------------------------------------- condição 1
# tentativa 4269
# valor da variação da energia: -143981.50918912888
# ----------------------------------------- condição 1
# tentativa 4270
# valor da variação da energia: -105808.24450063705
# ----------------------------------------- condição 1
# tentativa 4271
# valor da variação da energia: -42418.8838391304
# ----------------------------------------- condição 1
# tentativa 4272
# valor da variação da energia: 1.5289651726357937e6
# ----------------------------------------- condição 2
# tentativa 4273
# valor da variação da energia: 34527.86419701576
# ----------------------------------------- condição 2
# tentativa 4274
# valor da variação da energia: -197928.67579102516
# ----------------------------------------- condição 1
# tentativa 4275
# valor da variação da energia: 786121.280452013
# ----------------------------------------- condição 2
# tentativa 4276
# valor da variação da energia: -1.1133360280008316e6
# ----------------------------------------- condição 1
# tentativa 4277
# valor da variação da energia: 342214.7121787071
# ----------------------------------------- condição 2
# tentativa 4278
# valor da variação da energia: -87795.29198598862
# ----------------------------------------- condição 1
# tentativa 4279
# valor da variação da energia: -318393.771699667
# ----------------------------------------- condição 1
# tentativa 4280
# valor da variação da energia: 20509.17511487007
# ----------------------------------------- condição 2
# tentativa 4281
# valor da variação da energia: -909391.2118239403
# ----------------------------------------- condição 1
# tentativa 4282
# valor da variação da energia: 592674.985650301
# ----------------------------------------- condição 2
# tentativa 4283
# valor da variação da energia: -1.0692791713166237e6
# ----------------------------------------- condição 1
# tentativa 4284
# valor da variação da energia: 407687.0542743206
# ----------------------------------------- condição 2
# tentativa 4285
# valor da variação da energia: 342221.1358976364
# ----------------------------------------- condição 2
# tentativa 4286
# valor da variação da energia: 208597.34369301796
# ----------------------------------------- condição 2
# tentativa 4287
# valor da variação da energia: -75872.88642907143
# ----------------------------------------- condição 1
# tentativa 4288
# valor da variação da energia: -906035.2668375969
# ----------------------------------------- condição 1
# tentativa 4289
# valor da variação da energia: -10542.288229227066
# ----------------------------------------- condição 1
# tentativa 4290
# valor da variação da energia: 280958.5337781906
# ----------------------------------------- condição 2
# tentativa 4291
# valor da variação da energia: 587417.7153747082
# ----------------------------------------- condição 2
# tentativa 4292
# valor da variação da energia: -203382.32774186134
# ----------------------------------------- condição 1
# tentativa 4293
# valor da variação da energia: -210619.61849617958
# ----------------------------------------- condição 1
# tentativa 4294
# valor da variação da energia: -1.0937590739741325e6
# ----------------------------------------- condição 1
# tentativa 4295
# valor da variação da energia: 504631.8374080658
# ----------------------------------------- condição 2
# tentativa 4296
# valor da variação da energia: 744948.5401864052
# ----------------------------------------- condição 2
# tentativa 4297
# valor da variação da energia: -671400.8066847324
# ----------------------------------------- condição 1
# tentativa 4298
# valor da variação da energia: -362219.7015109062
# ----------------------------------------- condição 1
# tentativa 4299
# valor da variação da energia: 1.1559797545130253e6
# ----------------------------------------- condição 2
# tentativa 4300
# valor da variação da energia: -200443.6382472515
# ----------------------------------------- condição 1
# tentativa 4301
# valor da variação da energia: -437544.6109576225
# ----------------------------------------- condição 1
# tentativa 4302
# valor da variação da energia: -622225.7499949932
# ----------------------------------------- condição 1
# tentativa 4303
# valor da variação da energia: 175388.71351909637
# ----------------------------------------- condição 2
# tentativa 4304
# valor da variação da energia: -134688.45185661316
# ----------------------------------------- condição 1
# tentativa 4305
# valor da variação da energia: 380913.6119840145
# ----------------------------------------- condição 2
# tentativa 4306
# valor da variação da energia: 290253.2433395386
# ----------------------------------------- condição 2
# tentativa 4307
# valor da variação da energia: 58809.15113520622
# ----------------------------------------- condição 2
# tentativa 4308
# valor da variação da energia: -193250.21009659767
# ----------------------------------------- condição 1
# tentativa 4309
# valor da variação da energia: -717523.8847467899
# ----------------------------------------- condição 1
# tentativa 4310
# valor da variação da energia: 886784.161345005
# ----------------------------------------- condição 2
# tentativa 4311
# valor da variação da energia: -530649.0201220512
# ----------------------------------------- condição 1
# tentativa 4312
# valor da variação da energia: -371911.7140042782
# ----------------------------------------- condição 1
# tentativa 4313
# valor da variação da energia: 875256.4102489948
# ----------------------------------------- condição 2
# tentativa 4314
# valor da variação da energia: 1.4192048081350327e6
# ----------------------------------------- condição 2
# tentativa 4315
# valor da variação da energia: -1.0881742683587074e6
# ----------------------------------------- condição 1
# tentativa 4316
# valor da variação da energia: 759003.3950221539
# ----------------------------------------- condição 2
# tentativa 4317
# valor da variação da energia: -29976.733402967453
# ----------------------------------------- condição 1
# tentativa 4318
# valor da variação da energia: -330672.31808805466
# ----------------------------------------- condição 1
# tentativa 4319
# valor da variação da energia: -895944.3909711838
# ----------------------------------------- condição 1
# tentativa 4320
# valor da variação da energia: 95218.74351072311
# ----------------------------------------- condição 2
# tentativa 4321
# valor da variação da energia: -806195.0342664719
# ----------------------------------------- condição 1
# tentativa 4322
# valor da variação da energia: 133938.08784723282
# ----------------------------------------- condição 2
# tentativa 4323
# valor da variação da energia: -337745.2713775635
# ----------------------------------------- condição 1
# tentativa 4324
# valor da variação da energia: -108960.40818786621
# ----------------------------------------- condição 1
# tentativa 4325
# Excessive output truncated after 524317 bytes.
# valor da variação da energia: 126940.66431379318
# ----------------------------------------- condição 2
# tentativa 4326
# valor da variação da energia: -471717.35044670105
# ----------------------------------------- condição 1
# tentativa 4327
# valor da variação da energia: 192071.6783118248
# ----------------------------------------- condição 2
# tentativa 4328
# valor da variação da energia: -1.1901019675369263e6
# ----------------------------------------- condição 1
# tentativa 4329
# valor da variação da energia: 315259.90547180176
# ----------------------------------------- condição 2
# tentativa 4330
# valor da variação da energia: -940391.0575385094
# ----------------------------------------- condição 1
# tentativa 4331
# valor da variação da energia: 544195.5206825733
# ----------------------------------------- condição 2
# tentativa 4332
# valor da variação da energia: -626381.6261384487
# ----------------------------------------- condição 1
# tentativa 4333
# valor da variação da energia: 541479.1915853024
# ----------------------------------------- condição 2
# tentativa 4334
# valor da variação da energia: 179814.52387404442
# ----------------------------------------- condição 2
# tentativa 4335
# valor da variação da energia: 130158.19823098183
# ----------------------------------------- condição 2
# tentativa 4336
# valor da variação da energia: 18327.5197930336
# ----------------------------------------- condição 2
# tentativa 4337
# valor da variação da energia: -860668.1447298527
# ----------------------------------------- condição 1
# tentativa 4338
# valor da variação da energia: 586024.7851572037
# ----------------------------------------- condição 2
# tentativa 4339
# valor da variação da energia: -15356.173048257828
# ----------------------------------------- condição 1
# tentativa 4340
# valor da variação da energia: -547651.4202623367
# ----------------------------------------- condição 1
# tentativa 4341
# valor da variação da energia: 646545.8820762634
# ----------------------------------------- condição 2
# tentativa 4342
# valor da variação da energia: -410834.1914689541
# (Any[-253541.29769468307, 590194.5399844646, -807660.6562821865, 504900.57821035385, -632562.262326479, 177003.13078188896, 551341.3569545746, -739219.3454577923, 814697.403277874, -611466.2763185501], 1.0, Any[2.015481040798472e9, 2.0215294742759292e9, 1.928044820695877e9, 2.024960953900721e9, 1.9713269391668057e9, 2.0010113564870958e9, 1.9807749514275684e9, 1.9842543564893744e9, 1.9882068502803502e9, 2.01484721567515e9], [356.4772854936748 -386.07581351537897; 50.84774007315286 -758.7506408588454; … ; -965.3922235457233 740.9193000943421; 125.16404692699598 501.93498134529295])

# %%
energies
# Out:
# 10-element Vector{Any}:
#  2.0041405443860315e11
#  2.000896577402423e11
#  1.9606213120117093e11
#  1.988030404735497e11
#  2.0227243603404053e11
#  2.0163710684574506e11
#  2.0099279497699207e11
#  1.9546111356038947e11
#  1.993781005137647e11
#  2.0249960952114856e11

# %%
scalar = []
for i in 1:N
    push!(scalar,norm(velocidades[i,:]))
    end
scalar
# Out:
# 3000-element Vector{Any}:
#   7911.520224888779
#   4145.641624056614
#  10509.563788016356
#  10533.157090887993
#   2351.5698192385826
#   3754.4877115755535
#   7373.135981297951
#   5830.376186098633
#   7086.752605758979
#   7473.768216565703
#   8573.647762462862
#   8044.746471170643
#  10224.469544397962
#      ⋮
#   8223.276913424152
#   2373.4839144286416
#   8311.357155759822
#   2590.3819176623324
#   6468.510196316658
#  11444.555977842048
#  10304.696252954822
#  10551.37739667224
#   4401.197042981285
#   7899.934188952403
#   4043.4830498092524
#   9057.855374586668

# %%
Plots.xlabel!("Velocidades escalar")
Plots.histogram(scalar)

# %% [markdown]
# Para plotar a curva, vai exigir com que eu selecione o intervalo de valores e isso eu posso fazer usando a velocidade que dei de entrada

# %%
mean(scalar)
# Out:
# 7707.384361765231

# %%
N/velocities
# Out:
# 0.3

# %%
scalar
# Out:
# 3000-element Vector{Any}:
#   7911.520224888779
#   4145.641624056614
#  10509.563788016356
#  10533.157090887993
#   2351.5698192385826
#   3754.4877115755535
#   7373.135981297951
#   5830.376186098633
#   7086.752605758979
#   7473.768216565703
#   8573.647762462862
#   8044.746471170643
#  10224.469544397962
#      ⋮
#   8223.276913424152
#   2373.4839144286416
#   8311.357155759822
#   2590.3819176623324
#   6468.510196316658
#  11444.555977842048
#  10304.696252954822
#  10551.37739667224
#   4401.197042981285
#   7899.934188952403
#   4043.4830498092524
#   9057.855374586668

# %%
sort(scalar)
# Out:
# 3000-element Vector{Any}:
#    244.17015827249762
#    455.89209407731494
#    516.4969986929493
#    531.9768028071567
#    548.4947695607818
#    552.1897373663043
#    563.7232414008836
#    666.1631655744856
#    722.5619816201834
#    740.4087216815125
#    745.2684610371432
#    749.8454926138821
#    860.4222376149105
#      ⋮
#  13673.48634588896
#  13689.91536264071
#  13713.048595305045
#  13721.444486901137
#  13789.390786676071
#  13831.766942122127
#  13847.443267804305
#  13854.798265354286
#  13930.670451221926
#  13953.810022504986
#  13981.06767488549
#  14007.16568003248

# %%
teto = floor(maximum(scalar)+1)
# Out:
# 14008.0

# %%
classes = 30
# Out:
# 30

# %%
Δv = teto/(teto/N)
# Out:
# 3000.0

# %%
a = [i*Δv for i in 1:classes]
a
# Out:
# 30-element Vector{Float64}:
#   3000.0
#   6000.0
#   9000.0
#  12000.0
#  15000.0
#  18000.0
#  21000.0
#  24000.0
#  27000.0
#  30000.0
#  33000.0
#  36000.0
#  39000.0
#      ⋮
#  57000.0
#  60000.0
#  63000.0
#  66000.0
#  69000.0
#  72000.0
#  75000.0
#  78000.0
#  81000.0
#  84000.0
#  87000.0
#  90000.0

# %%
frequencias = []
k = 1
f = 0
for i in sort(scalar)
    if i > a[k]
        push!(frequencias,f)
        k += 1
        f = 0
    end
    f +=1
end
push!(frequencias,f)

frequencias
# Out:
# 5-element Vector{Any}:
#   209
#   615
#  1070
#   965
#   141

# %%
using Plotly

Plotly.plot(a,frequencias./N)
# Out:
# data: [
#   "scatter with fields type, x, and y"
# ]
#
# layout: "layout with fields margin and template"
